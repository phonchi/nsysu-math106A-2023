# %% [markdown]
# # Assignment 2

# %% [markdown]
# #### Student ID: *Double click to fill your student ID*
# #### Name: *Double click to fill your name*

# %% [markdown]
# ### (1) What statement creates a function?

# %% [markdown]
# (A) def
# (B) definition
# (C) Def
# (D) Definition

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# (A)

# %% [markdown]
# ### (2) According to the following program:
#
# ```
# def math():
#     math = 100
#     print(math)
#
# def nsysu():
#     math = "interesting"
#     math()
#     print(math)
#
# math = "I love math!"
# ```
# What should the ouputs look like when you run `nsysu()` and `print(math)`?

# %% [markdown]
# (A) I love math! I love math!, I love math!
# (B) interesting, I love math!
# (C) 100 100, 100
# (D) 100 interesting, I love math!

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# (D)

# %% [markdown]
# ### (3) What does `from math import *` if you have a file named **math.py**, which stores many functions?

# %% [markdown]
# (A) import the first function in math.py
# (B) import all functions from math.py
# (C) import the last function in math.py
# (D) meaningless

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# (B)

# %% [markdown]
# ### (4) How do you use the function `linspace()` in numpy according to `import numpy as np`?

# %% [markdown]
# (A) linspace()
# (B) np linspace()
# (C) numpy.linspace()
# (D) np.linspace()

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# (D)

# %% [markdown]
# ### (5) What is the data type of *None*?

# %% [markdown]
# (A) str
# (B) Nonetype
# (C) bool
# (D) list

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# (B)

# %% [markdown]
# ### (6) Why are functions adventageous to have in your programs?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# Functions reduce the need for duplicate code. This makes programs shorter, easier to read, and easier to update.

# %% [markdown]
# ### (7) What happens to variables in a local scope when the function call returns?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# When a function returns, the local scope is destroyed, and all the variables in it are forgotten.

# %% [markdown]
# ### (8) How can you force a variable in a function to refer to the global variable?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# A global statement will force a variable in a function to refer to the global variable.

# %% [markdown]
# ### (9) Write a function named `collatz()` that has one parameter named *number*. If *number* is even, then collatz should print *number* // 2 and return this value. If *number* is odd, then collatz should print and return 3 * *number* + 1.

# %%
def collatz(number):
    """
    Parameters
    ----------
    number: int
        The input number.
    Returns
    -------
    number: int
        The ouput number.
    """
    # coding your answer here
    if number % 2 == 0:
        number = number // 2
    else:
        number = 3 * number + 1
    print(number)
    return(number)

# %% [markdown]
# ### (10) Continuing from the previous question, write a program that allows the user to type in an interger and that keeps callig `collatz()` on the number until the function returns the value 1.

# %% [markdown]
# sample output
#
# ---
# Enter number:
# 3
# 10
# 5
# 16
# 8
# 4
# 2
# 1
#
# ---

# %%
# coding your answer here
number = int(input("Enter number: \n"))
while number != 1:
    number = collatz(number)
