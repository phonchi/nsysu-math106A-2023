# %% [markdown]
# # Assignment 6

# %% [markdown]
# #### Student ID: *Double click to fill your student ID*
# #### Name: *Double click to fill your name*

# %% [markdown]
# ### (1) Which of the following statement is False?

# %% [markdown]
# (A) `Python` does not have private attributes. Instead, you use naming conventions to design classes that encourage correct use.
#
# (B) Each new class you create can provide an `__init__` method that specifies how to initialize an object's data attributes.
#
# (C) We can access the attribute of the class using the dot notation.
#
# (D) If we access an attribute starting with `_`, an error will occur.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (2) Which of the following term describes the "has a" relationship between two classes?

# %% [markdown]
# (A) Composition
#
# (B) Inheritance
#
# (C) Polymorphism
#
# (D) Encapsulation

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (3) Which of the following statement is False?

# %% [markdown]
# (A) The `self` is used to represent the instance of the class in `Python`; if it is included in the method definition, it must come first before any other parameters.
#
# (B) When calling an instance method in `Python`, `self` must be passed explicitly and it must come first before any other arguments.
#
# (C) Any variable prefixed with `self` is available to every method in the class.
#
# (D) A class definition begins with the keyword class followed by the class’s name and a colon (:).

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (4) When we call the `print()` function and use an object as the argument, which special method will be called first?

# %% [markdown]
# (A) `__add__`
#
# (B) `__repr__`
#
# (C) `__str__`
#
# (D) `__init__`

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (5) Which of the following function can be used to check whether an object belongs to a specific class or not?

# %% [markdown]
# (A) `type()`
#
# (B) `isinstance()`
#
# (C) `dir()`
#
# (D) `id()`

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (6) Considering the following code cell. Try to modify the `integer` class so that when calling the `show()` function, it will not show the decimal point and the decimal part.

# %%
class floating:
    def __init__(self, num):
        self.num = num
    def show(self):
        print(f'{self.num:.1f}')

class integer(floating):
    def __init__(self, num):
        super().__init__(num)
    # Your code here

# %%
# Do not change the code below
egg = floating(3.53)
egg.show()
spam = integer(3)
spam.show()
# Out:
# 3.5
# 3

# %% [markdown]
# ### (7) Modify the above classes so that we can add the objects from the `integer` and the objects from the `floating` class together.
#
# Hint: You can try to override the method.

# %%
# Your code here

# %%
# Do not change the code below
egg = floating(3.53)
spam = integer(3)
print(spam + egg)
# Out:
# 6.529999999999999

# %% [markdown]
# ### (8) You may notice that the above calculation is not correct in the math sense, why? Try to import a built-in class in `Python` so that the numbers can be represented exactly. In addition,  calculate `3 + 3.53` exactly using the class.
#
# Hint: You may search the internet or use Copilot to give you suggestion

# %% [markdown]
# > Ans: *Double click to answer the question*

# %%
# Your code here

# %%
# Do not change the code below
print(egg + spam)
# Out:
# 6.53

# %% [markdown]
# ### (9) Design a `triangle` class that has two attributes, `base` and `height` and satisfies the following properties:
#
# 1. Create a constructor that accepts `base` and `height` from the user.
# 2. Using the naming convention to declare the two attributes as private data so that an error occurs when the user directly accesses these two attributes using dot notation.
# 3. Add getter (`get_base_height()`) and setter(`set_base_height`) to the class so that the two attributes can be set and get simultaneously via these methods.
# 4. Create a method `area()` for the class that returns the area of the triangle.
# 5. When the user prints out the triangle object, show the `base` and `height` of the triangle.

# %%
# Your code here

# %%
# Do not change the code below
t1 = trinagle(3, 4)
print(t1.area())
b, h = t1.get_base_height()
print(b, h)
t1.set_base_height(7, 24)
print(t1)
# Out:
# 6.0
# 3 4
# Triangle: base = 7, height = 24

# %% [markdown]
# ### (10) Design a `RightTriangle` class by inheriting from the above class and modifying the class so that only valid `base` and `height` can be set. Otherwise, you should raise an exception.
#
# Hint: You can raise an exception using the statement `raise ValueError('your message')`

# %%
# Your code here

# %%
# Do not change the code below
try:
    print(RightTriangle(3, 4))
    print(RightTriangle(7, 24))
    print(RightTriangle(3, 5))
    print(RightTriangle(-1, -1))
except:
    print('An error occured')
# Out:
# Triangle: base = 3, height = 4
# Triangle: base = 7, height = 24
# An error occured
