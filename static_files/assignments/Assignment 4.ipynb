# %% [markdown]
# # Assignment 4

# %% [markdown]
# #### Student ID: *Double click to fill your student ID*
# #### Name: *Double click to fill your name*

# %% [markdown]
# ### (1) What is a dictionary in Python?

# %% [markdown]
# (A) An ordered sequence of elements
# (B) A collection of unique elements
# (C) A collection of key-value pairs
# (D) A sequence of key-value pairs

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (2) How do you access a value in a dictionary?

# %% [markdown]
# (A) By its index
# (B) By its value
# (C) By its key
# (D) By its position

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (3) What is the syntax for adding an element to a dictionary in Python?

# %% [markdown]
# (A) my_dict.add(key, value)
# (B) my_dict[key] = value
# (C) my_dict.append(key, value)
# (D) my_dict.extend(key, value)

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (4) What is a set in Python?

# %% [markdown]
# (A) An ordered sequence of elements
# (B) A collection of unique elements
# (C) A collection of key-value pairs
# (D) A sequence of key-value pairs

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (5) How can you remove a specific value from a dictionary, without knowing its key?

# %% [markdown]
# (A) Use the 'pop' method with the value as an argument to remove the key-value pair associated with that value
# (B) Use the 'popitem' method to remove the last key-value pair in the dictionary
# (C) Use a loop to iterate over all the key-value pairs in the dictionary and remove the desired value
# (D) You cannot remove a value from a dictionary without knowing its key

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (6) What is the difference between a dictionary and a list in Python, and when would you choose to use one over the other?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (7) How do you check if a key exists in a dictionary in Python?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (8) How do you create a deep copy of a dictionary in Python?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (9) Suppose you have a list of student grades, and you want to find the top-performing student and the average grade for each subject. Write a program that does the following:
# 1.  Create a dictionary called `grades` that maps subject names to lists of grades for each student. Assume that each student has the same number of grades for each subject.
# 2.  Create a dictionary called `subject_averages` that maps subject names to their average grades across all students.
# 3.  Create a dictionary called `student_totals` that maps student names to their total grades across all subjects.
# 4.  Create a variable called `top_student` that contains the name of the student with the highest total grade.
# 5.  Print out the top-performing student's name and total grade, as well as the average grade for each subject.

# %%
grades = {
    'Math': [[90, 85, 92, 87, 94], [95, 88, 91, 89, 92], [87, 83, 85, 90, 89]],
    'Science': [[82, 88, 89, 91, 85], [90, 86, 88, 87, 92], [85, 83, 87, 84, 89]],
    'English': [[88, 85, 92, 86, 90], [91, 87, 89, 92, 85], [83, 86, 88, 87, 90]],
}

# coding your answer here

# %% [markdown]
# ### (10) Write a program that creates a dictionary `students` that maps student names to their ages. The program should prompt the user to enter the names and ages of at least three students, and then print out the contents of the `students` dictionary.

# %% [markdown]
# sample output:
#
# ---
# Enter a student name (or 'q' to quit): Sherry
# Enter the student's age: 18
# Enter a student name (or 'q' to quit): Money
# Enter the student's age: 3
# Enter a student name (or 'q' to quit): Steve
# Enter the student's age: 30
# Enter a student name (or 'q' to quit): q
# Student dictionary:
# {'Sherry': '18', 'Money': '3', 'Steve': '30'}
#
# ---

# %%
# coding your answer here
